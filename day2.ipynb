# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmya06-student/Data-Analytics-using-Python-Project/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  print("Welcome",name)
greet("Students")
# Out:
# Welcome Students

# %%
def greet():
   print("Hello")
greet()
# Out:
# Hello

# %%
def add(a,b):
  return a+b
result=add(10,20)
print(result)
# Out:
# 30
