# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmya06-student/Data-Analytics-using-Python-Project/blob/main/attendance_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_average(a,b,c):
   return(a+b+c)/3
try:
   a=int(input("enter 1st number:"))
   b=int(input("enter 2nd number:"))
   c=int(input("enter 3rd number:"))
   print("calculate_average=",calculate_average(a,b,c))
except ValueError:
   prinnt("invalid input")
# Out:
# enter 1st number:72
# enter 2nd number:5
# enter 3rd number:63
# calculate_average= 46.666666666666664
