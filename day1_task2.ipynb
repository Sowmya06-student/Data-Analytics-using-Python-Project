# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowmya06-student/Data-Analytics-using-Python-Project/blob/main/day1_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1=int(input("enter mark 1:"))
mark2=int(input("enter mark 2:"))
mark3=int(input("enter mark3:"))
total=mark1+mark2+mark3
average=total/3
print("Total",total)
print("Average",average)
if average>=50:
 print("pass")
else:
 print("fail")
# Out:
# enter mark 1:78
# enter mark 2:98
# enter mark3:63
# Total 239
# Average 79.66666666666667
# pass
